# %% [markdown]
# Author: Wolfgang Black <br>
# date_modified: 2022-07-24
#
# # Notebook purpose:
#
# This notebook is meant to be run in google colab. It is meant to simulate the behavior of main.py in a terminal environment. While one could run main.py from a nb interface on colab, in my experience it assigns too much temporary memory and breaks.
#
# This is the debugging notebook responsible for main.py

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
import sys
import json
base_dir = 'drive/MyDrive/Colab Notebooks/ProtCNN/src/'
os.chdir(base_dir)
from utils.datautils import *
from utils.modelutils import *

# %%
test_dict = {}

# %%
with open('./config/config.json') as json_data_file:
  config = json.load(json_data_file)
print(config)
# Out:
# {'data_config': {'DATA_DIR': './../../../PFAM_database/data/random_split/', 'MAX_LEN': 120, 'TEST_BATCH_SIZE': 100, 'TEST_RANGE': [0, 10000]}, 'model_config': {'NUM_MODELS': 1, 'MODEL_DIR': '../models/', 'NUM_RES_BLOCKS': 3, 'FILTERS': 128, 'D_RATE': [2, 3, 3], 'MAX_LEN': 120, 'DROPOUT': 0.5, 'L2_FACTOR': 0.0001, 'OPT': 'adam', 'LOSS': 'sparse_categorical_crossentropy', 'METRICS': ['accuracy'], 'EPOCHS': 5, 'BATCH_SIZE': 256}}

# %%
train_ds, validation_ds, config['model_config']['NUM_CLASSES'], config['model_config']['VOCAB_SIZE'] = build_training_datasets(
    config['data_config'])
# Out:
# building artifacts for training
#
# There are 17930 labels.
#
# AA dictionary formed. the length of dictionary is: 21.
#
# building dataset dictionaries
#
# building tensorflow datasets
#
# finished building training sets

# %%
config['data_config']['INFERENCE_DIR'] = build_train_model(config['model_config'], train_ds, validation_ds)
# Out:
# training model 0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 120, 21)]    0           []
#
#  conv1d (Conv1D)                (None, 120, 128)     2816        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 120, 128)    512         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 120, 128)     0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 120, 128)     16512       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 120, 128)    512         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 120, 128)     0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 120, 128)     49280       ['activation_1[0][0]']
#
# ...

# %%
test_dict = build_inference_data(config['data_config'])
# Out:
# getting training artifacts
# There are 17930 labels.
#
# AA dictionary formed. the length of dictionary is: 21.
#
# finished building data for inference

# %%
do_inference(test_dict, config)
# Out:
# Streaming output truncated to the last 5000 lines.
#          232       0.75      1.00      0.86         3
#          233       1.00      1.00      1.00         9
#          234       1.00      1.00      1.00         7
#          235       1.00      1.00      1.00         4
#          236       1.00      1.00      1.00         1
#          237       1.00      1.00      1.00         1
#          238       1.00      1.00      1.00         5
#          239       1.00      1.00      1.00         1
#          241       1.00      1.00      1.00         2
#          242       1.00      1.00      1.00         2
#          243       1.00      1.00      1.00         1
#          244       1.00      1.00      1.00         4
#          247       1.00      1.00      1.00         6
#          249       1.00      1.00      1.00        10
#          250       1.00      1.00      1.00        10
#          251       1.00      0.50      0.67         2
# ...
